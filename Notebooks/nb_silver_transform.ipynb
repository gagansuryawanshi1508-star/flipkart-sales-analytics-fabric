# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import pandas as pd
import io

bronze_path = "Files/bronze/flipkart_sales_messy/Selected_Extremely_Messy_Flipkart_Data.xlsx"

with open("/lakehouse/default/" + bronze_path, "rb") as f:
    raw_bytes = f.read()

pdf = pd.read_excel(io.BytesIO(raw_bytes))

print(pdf.shape)
display(pdf.head(20))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 3, Finished, Available, Finished, False)
# (123871, 19)
# SynapseWidget(Synapse.DataFrame, 3c09a78e-1d67-4c03-a5a8-6fada7d17708)

# %%
print("Rows and columns:", pdf.shape)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 4, Finished, Available, Finished, False)
# Rows and columns: (123871, 19)

# %%
print("\nColumns:")
for col in pdf.columns:
    print(col)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 5, Finished, Available, Finished, False)
# Columns:
# OrderDate
# OrderID
# Delivery Date
# CustomerID
# Customer Age
# Customer Gender
# Location
# Zone
# Delivery Type
# Product Category
# SubCategory
# Product
# Unit Price
# Shipping Fee
# Order Quantity
# Sale Price
# Status
# Reason
# Rating

# %%
print("\nData types:")
display(pdf.dtypes.reset_index().rename(columns={"index": "Column", 0: "Data Type"}))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 6, Finished, Available, Finished, False)
# Data types:
# SynapseWidget(Synapse.DataFrame, 359213cc-9ea7-47c3-8a35-764a7650e879)

# %%
print("\nNull counts:")
display(
    pdf.isna()
       .sum()
       .reset_index()
       .rename(columns={"index": "Column", 0: "Null Count"})
       .sort_values("Null Count", ascending=False)
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 7, Finished, Available, Finished, False)
# Null counts:
# SynapseWidget(Synapse.DataFrame, bf4d1323-593d-4b4c-8e3a-026290440527)

# %%
print("\nNull counts:")
display(
    pdf.isna()
       .sum()
       .reset_index()
       .rename(columns={"index": "Column", 0: "Null Count"})
       .sort_values("Null Count", ascending=False)
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 8, Finished, Available, Finished, False)
# Null counts:
# SynapseWidget(Synapse.DataFrame, d2b06e4e-f3d3-4337-8044-3d1d5deed557)

# %%
print(pdf["OrderID"].duplicated().sum())
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 9, Finished, Available, Finished, False)
# 17551

# %%
pdf.shape
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 10, Finished, Available, Finished, False)
# (123871, 19)

# %%
missing_values = pdf.isna().sum().sort_values(ascending=False)
display(missing_values)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 11, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a6648b61-4103-4f1d-8320-6f27ecc4b31e)

# %%
print("\nData types:")
display(pdf.dtypes)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 12, Finished, Available, Finished, False)
# Data types:
# SynapseWidget(Synapse.DataFrame, e84680e7-9b9e-41e5-a83c-1891c9d4d5c6)

# %%
duplicate_orders = pdf["OrderID"].duplicated().sum()
print("\nDuplicate OrderID rows:", duplicate_orders)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 13, Finished, Available, Finished, False)
# Duplicate OrderID rows: 17551

# %%
import numpy as np
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 14, Finished, Available, Finished, False)

# %%
import re
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 15, Finished, Available, Finished, False)

# %%
# removing row where every column is empty
pdf=pdf.dropna(how="all")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 16, Finished, Available, Finished, False)

# %%
pdf.shape
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 17, Finished, Available, Finished, False)
# (123871, 19)

# %%
text_columns = pdf.select_dtypes(include="object").columns
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 18, Finished, Available, Finished, False)

# %%
for column in text_columns:
    pdf[column] = pdf[column].astype(str).str.strip()
    pdf[column] = pdf[column].replace({
        "nan": np.nan,
        "None": np.nan,
        "": np.nan
    })
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 19, Finished, Available, Finished, False)

# %%
len(pdf)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 20, Finished, Available, Finished, False)
# 123871

# %%
pdf.head()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 21, Finished, Available, Finished, False)
#     OrderDate    OrderID  Delivery Date      CustomerID Customer Age  \
# 0  05-23-2020  5136025.0  Not Available  CUST-230547019           28
# 1  2015/08/07  5122109.0     2015-08-26       230488529           42
# 2  2019/10/06  5107179.0     2019/10/24       230521587           32
# 3  03/06/2015  5026545.0     2015-03-08  CUST-230568393          NaN
# 4  2017/09/07  5070813.0            NaN       230525690           50
#
#   Customer Gender       Location    Zone        Delivery Type  \
# 0            Male  GREATER ACCRA  Zone 1  Shipped from Abroad
# 1               F        Ashanti  Zone 3  Shipped from Abroad
# 2               F  greater accra   zone1  Shipped from Abroad
# 3               F          Volta    Zn 3              Express
# 4               M        Western  Zone 3                  NaN
#
#        Product Category                     SubCategory  \
# ...

# %%
pdf["Delivery Date"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 22, Finished, Available, Finished, False)
# 0         Not Available
# 1            2015-08-26
# 2            2019/10/24
# 3            2015-03-08
# 4                   NaN
#               ...
# 123866       2020-06-17
# 123867       2019-03-17
# 123868      10 Oct 2016
# 123869       09-01-2018
# 123870       01-05-2015
# Name: Delivery Date, Length: 123871, dtype: object

# %%
pdf["Delivery Date"] = pdf["Delivery Date"].replace({
    "Not Available": np.nan,
    "N/A": np.nan,
    "NA": np.nan
})
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 23, Finished, Available, Finished, False)

# %%
#converting date columns into real date
pdf["OrderDate"] = pd.to_datetime(pdf["OrderDate"], errors="coerce", format="mixed")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 24, Finished, Available, Finished, False)

# %%
pdf["Delivery Date"] = pd.to_datetime(pdf["Delivery Date"], errors="coerce", format="mixed")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 25, Finished, Available, Finished, False)

# %%
# OrderDate is required, so remove rows where it could not be parsed
pdf = pdf[pdf["OrderDate"].notna()]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 27, Finished, Available, Finished, False)

# %%
print("Rows after cleaning dates:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 29, Finished, Available, Finished, False)
# Rows after cleaning dates: 107562

# %%
display(
    pdf[["OrderDate", "Delivery Date"]].head(10)
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 30, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 99aa1056-7e63-435d-9d63-544291c3811c)

# %%
pdf["OrderID"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 31, Finished, Available, Finished, False)
# 0         5136025.0
# 1         5122109.0
# 2         5107179.0
# 3         5026545.0
# 4         5070813.0
#             ...
# 123865    5047053.0
# 123866    5119451.0
# 123868    5053946.0
# 123869    5076567.0
# 123870    5023473.0
# Name: OrderID, Length: 107562, dtype: float64

# %%
pdf = pdf[pdf["OrderID"].notna()]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 32, Finished, Available, Finished, False)

# %%
# Convert OrderID from float/text into whole number
pdf["OrderID"] = pdf["OrderID"].astype(int)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 33, Finished, Available, Finished, False)

# %%
pdf["OrderID"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 35, Finished, Available, Finished, False)
# 0         5136025
# 1         5122109
# 2         5107179
# 3         5026545
# 4         5070813
#            ...
# 123865    5047053
# 123866    5119451
# 123868    5053946
# 123869    5076567
# 123870    5023473
# Name: OrderID, Length: 101617, dtype: int64

# %%
# For duplicate orders, keep the row with the most filled values
pdf["missing_count"] = pdf.isna().sum(axis=1)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 37, Finished, Available, Finished, False)

# %%
pdf = (
    pdf.sort_values("missing_count")
       .drop_duplicates(subset="OrderID", keep="first")
       .drop(columns="missing_count")
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 38, Finished, Available, Finished, False)

# %%
print("Rows after cleaning OrderID and removing duplicates:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 39, Finished, Available, Finished, False)
# Rows after cleaning OrderID and removing duplicates: 92611

# %%
print("Remaining duplicate OrderIDs:", pdf["OrderID"].duplicated().sum())
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 40, Finished, Available, Finished, False)
# Remaining duplicate OrderIDs: 0

# %%
display(pdf.head())
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 41, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 62ccc041-b38d-4391-9a16-6d0bdeaae1e9)

# %%
pdf["CustomerID"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 42, Finished, Available, Finished, False)
# 34446     230554842
# 24244     230547048
# 10410     230533707
# 79138     230489999
# 10412     230480646
#             ...
# 117065    230509288
# 41764           NaN
# 84244           NaN
# 115535    230470059
# 48632     230550176
# Name: CustomerID, Length: 92611, dtype: object

# %%
pdf["CustomerID"] = (
    pdf["CustomerID"]
    .astype(str)
    .str.replace("CUST-", "", regex=False)
    .str.strip()
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 43, Finished, Available, Finished, False)

# %%
pdf["CustomerID"] = pd.to_numeric(pdf["CustomerID"], errors="coerce")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 44, Finished, Available, Finished, False)

# %%
# CustomerID is required
pdf = pdf[pdf["CustomerID"].notna()]
pdf["CustomerID"] = pdf["CustomerID"].astype(int)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 45, Finished, Available, Finished, False)

# %%
pdf["CustomerID"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 46, Finished, Available, Finished, False)
# 34446     230554842
# 24244     230547048
# 10410     230533707
# 79138     230489999
# 10412     230480646
#             ...
# 71850     230530441
# 108838    230549966
# 117065    230509288
# 115535    230470059
# 48632     230550176
# Name: CustomerID, Length: 88096, dtype: int64

# %%
pdf["Customer Age"].head(50)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 47, Finished, Available, Finished, False)
# 34446          61
# 24244          27
# 10410          33
# 79138          22
# 10412          18
# 56517          47
# 79139          47
# 40254          28
# 40246          41
# 40256     Unknown
# 91940          26
# 56499          58
# 10432          29
# 24229          18
# 79151          28
# 56492          22
# 115412         28
# 10424          53
# 24227          44
# 79136          46
# 40240     Unknown
# 79101          35
# 115459         24
# 10368          31
# 56563          39
# 40209          35
# 40217          34
# 115450         44
# 10405          24
# 79116          38
# 91967          50
# 79121          28
# 91959          22
# 56539         999
# 79128          34
# 10398          43
# 91950          46
# 104576         34
# 79168          28
# 56466          38
# 40290          46
# 40335          55
# 91879          49
# 40337         999
# 10521          29
# ...

# %%
pdf["Customer Age"] = pd.to_numeric(pdf["Customer Age"], errors="coerce")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 48, Finished, Available, Finished, False)

# %%
# Keep only realistic ages
pdf["Customer Age"] = pdf["Customer Age"].where(
    pdf["Customer Age"].between(18, 100)
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 49, Finished, Available, Finished, False)

# %%
# Fill missing ages with the median age
median_age = pdf["Customer Age"].median()
pdf["Customer Age"] = pdf["Customer Age"].fillna(median_age).astype(int)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 50, Finished, Available, Finished, False)

# %%
print("Rows after cleaning CustomerID and Customer Age:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 51, Finished, Available, Finished, False)
# Rows after cleaning CustomerID and Customer Age: 88096

# %%
pdf["Customer Age"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 52, Finished, Available, Finished, False)
# 34446     61
# 24244     27
# 10410     33
# 79138     22
# 10412     18
#           ..
# 71850     34
# 108838    29
# 117065    41
# 115535    30
# 48632     42
# Name: Customer Age, Length: 88096, dtype: int64

# %%
display(pdf[["Customer Age"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 53, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a7c24077-f4dd-4030-b64f-f2554a499827)

# %%
#Gender columns
pdf["Customer Gender"] = pdf["Customer Gender"].astype(str).str.strip().str.upper()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 56, Finished, Available, Finished, False)

# %%
gender_map = {
    "M": "M",
    "MALE": "M",
    "F": "F",
    "FEMALE": "F"
}
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 58, Finished, Available, Finished, False)

# %%
pdf["Customer Gender"] = pdf["Customer Gender"].map(gender_map)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 59, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Customer Gender"].notna()]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 60, Finished, Available, Finished, False)

# %%
display(pdf[["Customer Gender"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 61, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d07d9aa5-0f3e-4291-b815-fec65a2f47db)

# %%
#Location 
display(pdf[["Location"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 62, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, dc5a6e5c-a0d5-445a-9a1b-af023f045747)

# %%
valid_locations = [
    "Ahafo", "Amasaman", "Ashanti", "Bono", "Bono East", "Brong-Ahafo",
    "Central", "Dawhenya", "Dodowa", "Eastern", "Gbawe", "Greater Accra",
    "Kasoa", "Kitase", "North East", "Northern", "Oti", "Oyarifa",
    "Prampram", "Savannah", "Upper East", "Upper West", "Volta",
    "Weija", "Western", "Western North"
]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 63, Finished, Available, Finished, False)

# %%
location_corrections = {
    "Westerm": "Western",
    "Wesferm": "Western",
    "Ashant": "Ashanti",
    "Ashantii": "Ashanti",
    "Greeter Accra": "Greater Accra",
    "Greater  Accra": "Greater Accra",
    "Voltta": "Volta"
}
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 64, Finished, Available, Finished, False)

# %%
pdf["Location"] = pdf["Location"].astype(str).str.strip().str.title()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 65, Finished, Available, Finished, False)

# %%
pdf["Location"] = pdf["Location"].replace(location_corrections)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 66, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Location"].isin(valid_locations)]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 67, Finished, Available, Finished, False)

# %%
display(pdf[["Location"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 68, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 12c75327-c66c-4e3b-a0fe-4a817341f58e)

# %%
display(pdf[["Zone"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 69, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 0439db47-dd65-4d2a-922d-dac002320915)

# %%
pdf["Zone"] = pdf["Zone"].astype(str).str.extract(r"(\d)")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 70, Finished, Available, Finished, False)

# %%
pdf["Zone"] = "Zone " + pdf["Zone"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 71, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Zone"].isin(["Zone 1", "Zone 2", "Zone 3", "Zone 4"])]

print("Rows after cleaning gender, location, and zone:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 72, Finished, Available, Finished, False)
# Rows after cleaning gender, location, and zone: 71222

# %%
display(pdf[["Zone"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 73, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 4bc90b66-d3cd-4f1e-9392-f1c4ad1a58ca)

# %%
#Delivery Type
display(pdf[['Delivery Type']])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 74, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a1419c48-321f-466c-8e39-b54d8a85b4bc)

# %%
pdf["Delivery Type"] = (
    pdf["Delivery Type"]
    .astype(str)
    .str.strip()
    .str.lower()
    .str.replace("_", " ", regex=False)
    .str.replace("#", "", regex=False)
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 75, Finished, Available, Finished, False)

# %%
pdf["Delivery Type"] = pdf["Delivery Type"].replace({
    "express": "Express",
    "expresss": "Express",
    "standard delivery": "Standard Delivery",
    "shipped from abroad": "Shipped from Abroad"
})
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 76, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Delivery Type"].isin([
    "Express",
    "Standard Delivery",
    "Shipped from Abroad"
])]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 77, Finished, Available, Finished, False)

# %%
display(pdf[['Delivery Type']])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 78, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1e6e804c-6708-46ac-8add-09a2ede4e895)

# %%
#Product Category Columns
display(pdf[['Product Category']])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 79, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e33a9ed8-d678-4129-979f-b45f3b08ca87)

# %%
pdf["Product Category"] = (
    pdf["Product Category"]
    .astype(str)
    .str.strip()
    .str.replace("_", " ", regex=False)
    .str.replace("#", "", regex=False)
    .str.replace("*", "", regex=False)
    .str.replace("?", "", regex=False)
    .str.title()
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 80, Finished, Available, Finished, False)

# %%
display(pdf[['Product Category']])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 81, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c00e9500-6a21-4f73-8c6a-719cd6b1ed40)

# %%
valid_categories = [
    "Fashion",
    "Health And Beauty",
    "Electronics",
    "Home And Office",
    "Phones And Tablet"
]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 82, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Product Category"].isin(valid_categories)]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 83, Finished, Available, Finished, False)

# %%
#Sub Category
display(pdf[["SubCategory"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 84, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, eae77863-4911-4547-9fbf-4c7cc4a2e240)

# %%
pdf["SubCategory"] = (
    pdf["SubCategory"]
    .astype(str)
    .str.strip()
    .str.replace("#", "", regex=False)
    .str.replace("*", "", regex=False)
    .str.replace("?", "", regex=False)
    .str.replace("--", "", regex=False)
    .str.title()
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 85, Finished, Available, Finished, False)

# %%
valid_subcategories = [
    "Beauty And Personal Care",
    "Boy'S Fashion",
    "Digital Cameras",
    "Fragrances",
    "Girl'S Fashion",
    "Home Audio",
    "Home And Furniture",
    "Kitchen And Dinning",
    "Medical Supplies And Equipment",
    "Men'S Fashion",
    "Mobile Accessories",
    "Mobile Phones",
    "Tablets",
    "Tools And Home Improvement",
    "Vitamins & Dietary Supplements",
    "Women'S Fashion"
]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 86, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["SubCategory"].isin(valid_subcategories)]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 87, Finished, Available, Finished, False)

# %%
print("Rows after cleaning delivery and product columns:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 88, Finished, Available, Finished, False)
# Rows after cleaning delivery and product columns: 48900

# %%
display(pdf[["Delivery Type", "Product Category", "SubCategory"]].head(20))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 89, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6a601d6f-982c-429e-be9d-d08f1e31dc11)

# %%
display(pdf[["Product"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 90, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 603e43b3-b62c-421f-92fe-99d25822b68a)

# %%
pdf["Product"] = pdf["Product"].astype(str).str.strip()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 91, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Product"] != ""]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 92, Finished, Available, Finished, False)

# %%
display(pdf[["Product"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 93, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, f3f34668-fa4a-48e4-a345-15f32910e17d)

# %%
# Unit Price
display(pdf[["Unit Price"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 94, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1d7f4e5e-20cf-4923-a09e-6f180e775612)

# %%
pdf["Unit Price"] = pdf["Unit Price"].astype(str)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 95, Finished, Available, Finished, False)

# %%
pdf["Unit Price"] = pdf["Unit Price"].str.replace("$", "", regex=False)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 96, Finished, Available, Finished, False)

# %%
pdf["Unit Price"] = pdf["Unit Price"].str.replace(",", "", regex=False)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 97, Finished, Available, Finished, False)

# %%
pdf["Unit Price"] = pdf["Unit Price"].str.strip()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 98, Finished, Available, Finished, False)

# %%
pdf["Unit Price"] = pd.to_numeric(pdf["Unit Price"], errors="coerce")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 99, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Unit Price"] > 0]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 100, Finished, Available, Finished, False)

# %%
pdf["Unit Price"] = pdf["Unit Price"].astype(int)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 101, Finished, Available, Finished, False)

# %%
display(pdf[["Unit Price"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 102, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, bc55ac10-1377-4cfb-9457-2bfc19689a07)

# %%
# Shipping Fee
display(pdf[["Shipping Fee"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 103, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d15a8cbd-5ca9-48bd-9d58-49f502c98231)

# %%
pdf["Shipping Fee"] = pd.to_numeric(pdf["Shipping Fee"], errors="coerce")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 104, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Shipping Fee"] >= 0]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 105, Finished, Available, Finished, False)

# %%
pdf["Shipping Fee"] = pdf["Shipping Fee"].astype(int)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 106, Finished, Available, Finished, False)

# %%
display(pdf[["Shipping Fee"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 107, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c76952b8-31a9-4458-b551-a550d4fe7408)

# %%
# Order Quantity
display(pdf[["Order Quantity"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 108, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8034580c-fcd4-40a3-a780-e7347c58daa6)

# %%
pdf["Order Quantity"] = pdf["Order Quantity"].astype(str).str.strip().str.lower()

pdf["Order Quantity"] = pdf["Order Quantity"].replace("none", np.nan)
pdf["Order Quantity"] = pdf["Order Quantity"].replace("?", np.nan)
pdf["Order Quantity"] = pdf["Order Quantity"].replace("nan", np.nan)
pdf["Order Quantity"] = pdf["Order Quantity"].replace("", np.nan)
pdf["Order Quantity"] = pdf["Order Quantity"].replace("0", np.nan)

pdf["Order Quantity"] = pd.to_numeric(pdf["Order Quantity"], errors="coerce")

pdf = pdf[pdf["Order Quantity"].between(1, 10)]

pdf["Order Quantity"] = pdf["Order Quantity"].astype(int)

print("Remaining bad values:", pdf["Order Quantity"].isna().sum())
display(pdf[["Order Quantity"]].head(20))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 109, Finished, Available, Finished, False)
# Remaining bad values: 0
# SynapseWidget(Synapse.DataFrame, 9f50e714-81bf-4b9e-8a42-b9b03f10b3ed)

# %%
# Sale Price
display(pdf[["Sale Price"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 110, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1901fed7-cf7f-4e8a-95ef-be9f6ae8d8c1)

# %%
sale_price_audit = pdf[pdf["Sale Price"].astype(str).str.contains("INR", case=False, na=False)].copy()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 111, Finished, Available, Finished, False)

# %%
pdf["Sale Price"] = pdf["Sale Price"].astype(str)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 112, Finished, Available, Finished, False)

# %%
pdf["Sale Price"] = pdf["Sale Price"].str.replace("INR", "", case=False, regex=False)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 113, Finished, Available, Finished, False)

# %%
pdf["Sale Price"] = pdf["Sale Price"].str.replace("USD", "", case=False, regex=False)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 114, Finished, Available, Finished, False)

# %%
pdf["Sale Price"] = pdf["Sale Price"].str.replace("GHS", "", case=False, regex=False)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 115, Finished, Available, Finished, False)

# %%
pdf["Sale Price"] = pdf["Sale Price"].str.replace(",", "", regex=False)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 116, Finished, Available, Finished, False)

# %%
pdf["Sale Price"] = pdf["Sale Price"].str.strip()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 117, Finished, Available, Finished, False)

# %%
pdf["Sale Price"] = pd.to_numeric(pdf["Sale Price"], errors="coerce")
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 118, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Sale Price"] > 0]
pdf["Sale Price"] = pdf["Sale Price"].astype(int)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 119, Finished, Available, Finished, False)

# %%
print("Rows after cleaning product and price columns:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 120, Finished, Available, Finished, False)
# Rows after cleaning product and price columns: 34830

# %%
display(pdf[["Product", "Unit Price", "Shipping Fee", "Order Quantity", "Sale Price"]].head(120))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 121, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8b370e56-780b-4088-928b-be6b5a3b6df3)

# %%
#status columns
display(pdf[["Status"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 122, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c2a7be9e-2d89-41e0-801d-167c88465f88)

# %%
pdf["Status"] = pdf["Status"].astype(str).str.strip().str.lower()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 123, Finished, Available, Finished, False)

# %%
pdf["Status"] = pdf["Status"].replace({
    "returned": "Returned",
    "return": "Returned",
    "returnd": "Returned",
    "delivered": "Delivered",
    "deliver": "Delivered",
    "deliverd": "Delivered"
})
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 124, Finished, Available, Finished, False)

# %%
pdf = pdf[pdf["Status"].isin(["Returned", "Delivered"])]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 125, Finished, Available, Finished, False)

# %%
display(pdf[["Status"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 126, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 3a7b6bc4-9731-4dbf-99cd-0d6df06afa11)

# %%
# Reason
display(pdf[["Reason"]])
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 127, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1a408aba-75bb-4576-a1f8-3932e84cf441)

# %%
pdf["Reason"] = pdf["Reason"].astype(str).str.strip()
pdf["Reason"] = pdf["Reason"].replace("nan", np.nan)
pdf["Reason"] = pdf["Reason"].replace("", np.nan)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 128, Finished, Available, Finished, False)

# %%
# Delivered orders should not have a return 
pdf.loc[pdf["Status"] == "Delivered", "Reason"] = np.nan
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 129, Finished, Available, Finished, False)

# %%
pdf.shape
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 130, Finished, Available, Finished, False)
# (33105, 19)

# %%
pdf["Rating"] = pd.to_numeric(pdf["Rating"], errors="coerce")
pdf = pdf[pdf["Rating"].between(1, 5)]
pdf["Rating"] = pdf["Rating"].astype(int)

print("Rows after cleaning status, reason, and rating:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 131, Finished, Available, Finished, False)
# Rows after cleaning status, reason, and rating: 30151

# %%
pdf.shape
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 132, Finished, Available, Finished, False)
# (30151, 19)

# %%
#Derived columns 
pdf["Delivery Days"] = (pdf["Delivery Date"] - pdf["OrderDate"]).dt.days
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 133, Finished, Available, Finished, False)

# %%
pdf["Total Revenue"] = pdf["Sale Price"] * pdf["Order Quantity"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 134, Finished, Available, Finished, False)

# %%
pdf["Discount Amount"] = (pdf["Unit Price"] * pdf["Order Quantity"]) - pdf["Sale Price"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 135, Finished, Available, Finished, False)

# %%
pdf["Discount Pct"] = (
    pdf["Discount Amount"] / (pdf["Unit Price"] * pdf["Order Quantity"]) * 100
).round(2)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 136, Finished, Available, Finished, False)

# %%
pdf["Is Returned"] = 0
pdf.loc[pdf["Status"] == "Returned", "Is Returned"] = 1
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 137, Finished, Available, Finished, False)

# %%
pdf["Order Year"] = pdf["OrderDate"].dt.year
pdf["Order Month"] = pdf["OrderDate"].dt.month
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 138, Finished, Available, Finished, False)

# %%
print("Rows after creating derived columns:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 139, Finished, Available, Finished, False)
# Rows after creating derived columns: 30151

# %%
display(
    pdf[
        [
            "OrderDate",
            "Delivery Date",
            "Delivery Days",
            "Total Revenue",
            "Discount Amount",
            "Discount Pct",
            "Is Returned",
            "Order Year",
            "Order Month"
        ]
    ].head(200)
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 140, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 54fd6b38-3438-4039-9706-d4a6d557afac)

# %%
bad_delivery_days = pdf[pdf["Delivery Days"] < 0].copy()
bad_discount_rows = pdf[pdf["Discount Amount"] < 0].copy()
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 141, Finished, Available, Finished, False)

# %%
print("Rows with negative delivery days:", len(bad_delivery_days))
print("Rows with negative discount:", len(bad_discount_rows))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 142, Finished, Available, Finished, False)
# Rows with negative delivery days: 2755
# Rows with negative discount: 6819

# %%
# Remove rows where delivery date is before order date
pdf = pdf[pdf["Delivery Days"] >= 0]


# Remove rows where sale price is greater than unit price * quantity
pdf = pdf[pdf["Discount Amount"] >= 0]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 143, Finished, Available, Finished, False)

# %%
# Recalculate discount percent after filtering
pdf["Discount Pct"] = (
    pdf["Discount Amount"] / (pdf["Unit Price"] * pdf["Order Quantity"]) * 100
).round(2)

print("Rows after removing negative delivery/discount records:", len(pdf))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 144, Finished, Available, Finished, False)
# Rows after removing negative delivery/discount records: 19028

# %%
display(
    pdf[
        [
            "OrderDate",
            "Delivery Date",
            "Delivery Days",
            "Unit Price",
            "Order Quantity",
            "Sale Price",
            "Discount Amount",
            "Discount Pct"
        ]
    ].head(200)
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 145, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 4c1a9ab1-c635-41b8-b7f3-4333b65f4f37)

# %%
pdf["Is Returned"] = (pdf["Status"] == "Returned").astype(int)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 146, Finished, Available, Finished, False)

# %%
pdf["Total Revenue"] = pdf["Sale Price"] * pdf["Order Quantity"]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 147, Finished, Available, Finished, False)

# %%
pdf["Order Year"] = pdf["OrderDate"].dt.year
pdf["Order Month"] = pdf["OrderDate"].dt.month
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 148, Finished, Available, Finished, False)

# %%
display(
    pdf[
        [
            "Sale Price",
            "Order Quantity",
            "Total Revenue",
            "Status",
            "Is Returned",
            "OrderDate",
            "Order Year",
            "Order Month"
        ]
    ].head(20)
)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 149, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 43457fa0-57a9-4d9b-b521-be886304d8cb)

# %%
print("Final row count:", len(pdf))
print("Final column count:", len(pdf.columns))

print("\nMissing values:")
display(pdf.isna().sum())

print("\nDuplicate OrderID count:")
print(pdf["OrderID"].duplicated().sum())

print("\nDate check:")
print("Negative delivery days:", (pdf["Delivery Days"] < 0).sum())

print("\nDiscount check:")
print("Negative discount amount:", (pdf["Discount Amount"] < 0).sum())
print("Negative discount percent:", (pdf["Discount Pct"] < 0).sum())

display(pdf.head(20))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 150, Finished, Available, Finished, False)
# Final row count: 19028
# Final column count: 26
#
# Missing values:
# SynapseWidget(Synapse.DataFrame, a3ec45bc-8745-4421-81b0-2f8dc668fbcd)
# Duplicate OrderID count:
# 0
#
# Date check:
# Negative delivery days: 0
#
# Discount check:
# Negative discount amount: 0
# Negative discount percent: 0
# SynapseWidget(Synapse.DataFrame, 8031df6e-c563-4f35-b8e1-08917e9890d9)

# %%
missing_values = pdf.isna().sum()
missing_values = missing_values[missing_values > 0]

missing_values = missing_values.reset_index()
missing_values.columns = ["Column", "Missing Count"]

display(missing_values)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 151, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c9d62e3a-0ba2-487f-89ca-7006a4dc1765)

# %%
print("Rows:", len(pdf))
print("Columns:", len(pdf.columns))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 153, Finished, Available, Finished, False)
# Rows: 19028
# Columns: 26

# %%
print("\nMissing values:")
missing_values = pdf.isna().sum()
missing_values = missing_values[missing_values > 0]
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 155, Finished, Available, Finished, False)
# Missing values:

# %%
print("Missing OrderDate:", pdf["OrderDate"].isna().sum())
print("Delivery date before order date:", (pdf["Delivery Days"] < 0).sum())
print("Very high delivery days over 60:", (pdf["Delivery Days"] > 60).sum())
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 156, Finished, Available, Finished, False)
# Missing OrderDate: 0
# Delivery date before order date: 0
# Very high delivery days over 60: 1845

# %%
print("Gender values:", sorted(pdf["Customer Gender"].dropna().unique()))
print("Status values:", sorted(pdf["Status"].dropna().unique()))
print("Zone values:", sorted(pdf["Zone"].dropna().unique()))
print("Delivery Type values:", sorted(pdf["Delivery Type"].dropna().unique()))
print("Product Category values:", sorted(pdf["Product Category"].dropna().unique()))
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 157, Finished, Available, Finished, False)
# Gender values: ['F', 'M']
# Status values: ['Delivered', 'Returned']
# Zone values: ['Zone 1', 'Zone 2', 'Zone 3', 'Zone 4']
# Delivery Type values: ['Express', 'Shipped from Abroad', 'Standard Delivery']
# Product Category values: ['Electronics', 'Fashion', 'Health And Beauty', 'Home And Office', 'Phones And Tablet']

# %%
pdf = pdf.rename(columns={
    "Delivery Date": "DeliveryDate",
    "Customer Age": "CustomerAge",
    "Customer Gender": "CustomerGender",
    "Delivery Type": "DeliveryType",
    "Product Category": "ProductCategory",
    "Unit Price": "UnitPrice",
    "Shipping Fee": "ShippingFee",
    "Order Quantity": "OrderQuantity",
    "Sale Price": "SalePrice",
    "Delivery Days": "DeliveryDays",
    "Total Revenue": "TotalRevenue",
    "Discount Amount": "DiscountAmount",
    "Discount Pct": "DiscountPct",
    "Is Returned": "IsReturned",
    "Order Year": "OrderYear",
    "Order Month": "OrderMonth"
})

print(pdf.columns)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 158, Finished, Available, Finished, False)
# Index(['OrderDate', 'OrderID', 'DeliveryDate', 'CustomerID', 'CustomerAge',
#        'CustomerGender', 'Location', 'Zone', 'DeliveryType', 'ProductCategory',
#        'SubCategory', 'Product', 'UnitPrice', 'ShippingFee', 'OrderQuantity',
#        'SalePrice', 'Status', 'Reason', 'Rating', 'DeliveryDays',
#        'TotalRevenue', 'DiscountAmount', 'DiscountPct', 'IsReturned',
#        'OrderYear', 'OrderMonth'],
#       dtype='object')

# %%
silver_df = spark.createDataFrame(pdf)

silver_df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable("silver_flipkart_sales")

print("Silver table saved successfully")
print("Rows saved:", silver_df.count())
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 159, Finished, Available, Finished, False)
# Silver table saved successfully
# Rows saved: 19028

# %%
df = spark.sql("SELECT * FROM lh_flipkart_sales.dbo.silver_flipkart_sales LIMIT 1000")
display(df)
# Out:
# StatementMeta(, f443df56-f6d2-4160-b376-6d0121064d7b, 160, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 86572fd8-d6a0-4faf-a5ac-ab8f6e30c829)

# %%
spark.table("silver_flipkart_sales").show(5)
# Out:
# StatementMeta(, 567c403b-804d-4b80-9e88-7728d1b6cc28, 3, Finished, Available, Finished, False)
# +-------------------+-------+-------------------+----------+-----------+--------------+-------------+------+-------------------+-----------------+--------------------+--------------------+---------+-----------+-------------+---------+--------+--------------------+------+------------+------------+--------------+-----------+----------+---------+----------+
# |          OrderDate|OrderID|       DeliveryDate|CustomerID|CustomerAge|CustomerGender|     Location|  Zone|       DeliveryType|  ProductCategory|         SubCategory|             Product|UnitPrice|ShippingFee|OrderQuantity|SalePrice|  Status|              Reason|Rating|DeliveryDays|TotalRevenue|DiscountAmount|DiscountPct|IsReturned|OrderYear|OrderMonth|
# ...
